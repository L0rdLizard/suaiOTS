# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import comb
from numpy.random import default_rng

rng = default_rng()

q = 16
T = 2e-6
f0 = 20e6
dtf = 1 / T

Ns = 50
A = 1
dt = 1 / (Ns * f0)
t = np.arange(0, T, dt)

f = np.zeros(q)
s = np.zeros((q, len(t)))
f1 = np.zeros((q, len(t)))
f2 = np.zeros((q, len(t)))

for i in range(q):
    f[i] = f0 + (i) * dtf
    s[i, :] = A * np.cos(2 * np.pi * f[i] * t)
    f1[i, :] = np.sqrt(2 / T) * np.cos(2 * np.pi * f[i] * t)
    f2[i, :] = np.sqrt(2 / T) * np.sin(2 * np.pi * f[i] * t)

E = np.linalg.norm(s[0, :]) ** 2
Nerrmax = 50
num_tests = 300000
SNRdb = np.arange(1, 15, 1)
Pe = np.zeros(len(SNRdb))
Pe_teor = np.zeros(len(SNRdb))

e = 1
m = np.sqrt(e / 2)
sigm = np.sqrt((1 - e) / 2)

for ns in range(len(SNRdb)):
    SNR = 10 ** (SNRdb[ns] / 10)
    N0 = E / SNR
    sigma = np.sqrt(N0 / 2)
    Nerr = 0
    Ntest = 0
    Pe_t = 0

    for j in range(q - 1):
        Pe_t = Pe_t + comb(q-1,j) * ((-1)**(j + 1)) * (1/(1+j+j*(1-e)*E/N0)) * np.exp(- (j*e*E/N0)/(1+j+j*(1-e)*E/N0))

    last_test = Ntest

    while (Nerr < Nerrmax):
        i = np.floor(rng.random() * q).astype(int)
        x = rng.normal(m, sigm)
        y = rng.normal(m, sigm)
        m_ = np.sqrt(x ** 2 + y ** 2)

        r = m_ * A * np.cos(2 * np.pi * f[i] * t + 2 * np.pi * rng.random()) + sigma * rng.standard_normal(len(t))
        rci = np.zeros(q)
        rsi = np.zeros(q)
        ni = np.zeros(q)

        for j in range(q):
            rci[j] = np.dot(r, f1[j, :])
            rsi[j] = np.dot(r, f2[j, :])
            ni[j] = (rci[j] ** 2) + (rsi[j] ** 2)

        max_value, index_max = np.max(ni), np.argmax(ni)
        if index_max != i:
            Nerr = Nerr + 1
            print(f'{index_max} != {i}')
            print(f'SNRdb = {SNRdb[ns]} | {Nerr} Nerr | {Ntest} Ntest')

        Ntest = Ntest + 1

        if (Ntest - last_test > num_tests):
            print(f'> {num_tests} tests')
            print('Pe ~= 0')
            break

    Pe[ns] = Nerr / Ntest
    Pe_teor[ns] = Pe_t
    print(f'Pe {Pe[ns]}')

plt.figure(1)
plt.semilogy(SNRdb, Pe, 'r', SNRdb, Pe_teor, 'blue', linewidth=2)
plt.xlabel('SNRdb')
plt.ylabel('Pe')
plt.legend(['Pe_p_r_a_c_t', 'Pe_t_e_o_r'])
plt.grid(True)
plt.show()
# Out:
# 12 != 6
# SNRdb = 1 | 1 Nerr | 0 Ntest
# 14 != 15
# SNRdb = 1 | 2 Nerr | 1 Ntest
# 15 != 13
# SNRdb = 1 | 3 Nerr | 2 Ntest
# 9 != 7
# SNRdb = 1 | 4 Nerr | 3 Ntest
# 15 != 14
# SNRdb = 1 | 5 Nerr | 4 Ntest
# 8 != 2
# SNRdb = 1 | 6 Nerr | 6 Ntest
# 10 != 12
# SNRdb = 1 | 7 Nerr | 7 Ntest
# 15 != 3
# SNRdb = 1 | 8 Nerr | 8 Ntest
# 13 != 8
# SNRdb = 1 | 9 Nerr | 9 Ntest
# 1 != 7
# SNRdb = 1 | 10 Nerr | 10 Ntest
# 0 != 10
# SNRdb = 1 | 11 Nerr | 11 Ntest
# 1 != 8
# SNRdb = 1 | 12 Nerr | 12 Ntest
# 3 != 1
# SNRdb = 1 | 13 Nerr | 15 Ntest
# 4 != 3
# SNRdb = 1 | 14 Nerr | 16 Ntest
# 5 != 10
# SNRdb = 1 | 15 Nerr | 17 Ntest
# 8 != 15
# SNRdb = 1 | 16 Nerr | 18 Ntest
# 9 != 0
# SNRdb = 1 | 17 Nerr | 19 Ntest
# 12 != 8
# SNRdb = 1 | 18 Nerr | 20 Ntest
# 12 != 8
# SNRdb = 1 | 19 Nerr | 21 Ntest
# 0 != 3
# SNRdb = 1 | 20 Nerr | 22 Ntest
# 4 != 13
# SNRdb = 1 | 21 Nerr | 23 Ntest
# 5 != 1
# SNRdb = 1 | 22 Nerr | 24 Ntest
# 3 != 12
# SNRdb = 1 | 23 Nerr | 25 Ntest
# 4 != 5
# SNRdb = 1 | 24 Nerr | 26 Ntest
# 2 != 8
# SNRdb = 1 | 25 Nerr | 28 Ntest
# 4 != 1
# SNRdb = 1 | 26 Nerr | 29 Ntest
# 14 != 4
# SNRdb = 1 | 27 Nerr | 30 Ntest
# 4 != 2
# SNRdb = 1 | 28 Nerr | 31 Ntest
# 9 != 2
# SNRdb = 1 | 29 Nerr | 32 Ntest
# 11 != 8
# SNRdb = 1 | 30 Nerr | 33 Ntest
# 11 != 4
# SNRdb = 1 | 31 Nerr | 34 Ntest
# 14 != 13
# SNRdb = 1 | 32 Nerr | 35 Ntest
# 5 != 4
# SNRdb = 1 | 33 Nerr | 37 Ntest
# 8 != 10
# SNRdb = 1 | 34 Nerr | 39 Ntest
# 4 != 3
# SNRdb = 1 | 35 Nerr | 41 Ntest
# 4 != 2
# SNRdb = 1 | 36 Nerr | 42 Ntest
# 5 != 3
# SNRdb = 1 | 37 Nerr | 44 Ntest
# 3 != 2
# SNRdb = 1 | 38 Nerr | 45 Ntest
# 5 != 1
# SNRdb = 1 | 39 Nerr | 47 Ntest
# 7 != 12
# SNRdb = 1 | 40 Nerr | 49 Ntest
# 3 != 11
# SNRdb = 1 | 41 Nerr | 50 Ntest
# 1 != 12
# SNRdb = 1 | 42 Nerr | 51 Ntest
# 14 != 5
# SNRdb = 1 | 43 Nerr | 54 Ntest
# 14 != 13
# SNRdb = 1 | 44 Nerr | 55 Ntest
# 15 != 1
# SNRdb = 1 | 45 Nerr | 56 Ntest
# 0 != 1
# SNRdb = 1 | 46 Nerr | 57 Ntest
# 9 != 15
# SNRdb = 1 | 47 Nerr | 58 Ntest
# 15 != 14
# SNRdb = 1 | 48 Nerr | 59 Ntest
# 10 != 15
# SNRdb = 1 | 49 Nerr | 60 Ntest
# 1 != 14
# SNRdb = 1 | 50 Nerr | 61 Ntest
# Pe 0.8064516129032258
# 3 != 4
# SNRdb = 2 | 1 Nerr | 0 Ntest
# 13 != 10
# SNRdb = 2 | 2 Nerr | 1 Ntest
# 7 != 0
# SNRdb = 2 | 3 Nerr | 2 Ntest
# 1 != 5
# SNRdb = 2 | 4 Nerr | 3 Ntest
# 15 != 10
# SNRdb = 2 | 5 Nerr | 4 Ntest
# 15 != 0
# SNRdb = 2 | 6 Nerr | 6 Ntest
# 11 != 0
# SNRdb = 2 | 7 Nerr | 7 Ntest
# 9 != 11
# SNRdb = 2 | 8 Nerr | 8 Ntest
# 10 != 15
# SNRdb = 2 | 9 Nerr | 10 Ntest
# 4 != 10
# SNRdb = 2 | 10 Nerr | 11 Ntest
# 9 != 1
# SNRdb = 2 | 11 Nerr | 12 Ntest
# 15 != 10
# SNRdb = 2 | 12 Nerr | 13 Ntest
# 10 != 4
# SNRdb = 2 | 13 Nerr | 14 Ntest
# 1 != 11
# SNRdb = 2 | 14 Nerr | 15 Ntest
# 12 != 2
# SNRdb = 2 | 15 Nerr | 17 Ntest
# 11 != 4
# SNRdb = 2 | 16 Nerr | 19 Ntest
# 0 != 7
# SNRdb = 2 | 17 Nerr | 20 Ntest
# 13 != 9
# SNRdb = 2 | 18 Nerr | 21 Ntest
# 0 != 9
# SNRdb = 2 | 19 Nerr | 22 Ntest
# 13 != 0
# SNRdb = 2 | 20 Nerr | 23 Ntest
# 8 != 5
# SNRdb = 2 | 21 Nerr | 24 Ntest
# 1 != 13
# SNRdb = 2 | 22 Nerr | 27 Ntest
# 13 != 8
# SNRdb = 2 | 23 Nerr | 28 Ntest
# 13 != 0
# SNRdb = 2 | 24 Nerr | 31 Ntest
# 0 != 13
# SNRdb = 2 | 25 Nerr | 32 Ntest
# 10 != 13
# SNRdb = 2 | 26 Nerr | 34 Ntest
# 9 != 3
# SNRdb = 2 | 27 Nerr | 35 Ntest
# 1 != 14
# SNRdb = 2 | 28 Nerr | 37 Ntest
# 7 != 11
# SNRdb = 2 | 29 Nerr | 39 Ntest
# 12 != 14
# SNRdb = 2 | 30 Nerr | 40 Ntest
# 14 != 13
# SNRdb = 2 | 31 Nerr | 41 Ntest
# 5 != 12
# SNRdb = 2 | 32 Nerr | 44 Ntest
# 2 != 3
# SNRdb = 2 | 33 Nerr | 45 Ntest
# 7 != 12
# SNRdb = 2 | 34 Nerr | 46 Ntest
# 0 != 8
# SNRdb = 2 | 35 Nerr | 48 Ntest
# 4 != 7
# SNRdb = 2 | 36 Nerr | 50 Ntest
# 15 != 8
# SNRdb = 2 | 37 Nerr | 53 Ntest
# 8 != 15
# SNRdb = 2 | 38 Nerr | 54 Ntest
# 3 != 11
# SNRdb = 2 | 39 Nerr | 56 Ntest
# 9 != 10
# SNRdb = 2 | 40 Nerr | 59 Ntest
# 3 != 5
# SNRdb = 2 | 41 Nerr | 60 Ntest
# 7 != 15
# SNRdb = 2 | 42 Nerr | 61 Ntest
# 0 != 3
# SNRdb = 2 | 43 Nerr | 62 Ntest
# 14 != 12
# SNRdb = 2 | 44 Nerr | 64 Ntest
# 7 != 4
# SNRdb = 2 | 45 Nerr | 65 Ntest
# 15 != 10
# SNRdb = 2 | 46 Nerr | 66 Ntest
# 14 != 12
# SNRdb = 2 | 47 Nerr | 68 Ntest
# 14 != 13
# SNRdb = 2 | 48 Nerr | 69 Ntest
# 12 != 9
# SNRdb = 2 | 49 Nerr | 71 Ntest
# 10 != 15
# SNRdb = 2 | 50 Nerr | 72 Ntest
# Pe 0.684931506849315
# 14 != 13
# SNRdb = 3 | 1 Nerr | 1 Ntest
# 11 != 8
# SNRdb = 3 | 2 Nerr | 4 Ntest
# 11 != 1
# SNRdb = 3 | 3 Nerr | 6 Ntest
# 13 != 15
# SNRdb = 3 | 4 Nerr | 7 Ntest
# 4 != 10
# SNRdb = 3 | 5 Nerr | 9 Ntest
# 10 != 11
# SNRdb = 3 | 6 Nerr | 10 Ntest
# 12 != 10
# SNRdb = 3 | 7 Nerr | 11 Ntest
# 5 != 3
# SNRdb = 3 | 8 Nerr | 12 Ntest
# 4 != 10
# SNRdb = 3 | 9 Nerr | 14 Ntest
# 12 != 8
# SNRdb = 3 | 10 Nerr | 15 Ntest
# 11 != 3
# SNRdb = 3 | 11 Nerr | 16 Ntest
# 4 != 7
# SNRdb = 3 | 12 Nerr | 17 Ntest
# 10 != 3
# SNRdb = 3 | 13 Nerr | 18 Ntest
# 1 != 13
# SNRdb = 3 | 14 Nerr | 21 Ntest
# 1 != 13
# SNRdb = 3 | 15 Nerr | 23 Ntest
# 1 != 0
# SNRdb = 3 | 16 Nerr | 26 Ntest
# 9 != 10
# SNRdb = 3 | 17 Nerr | 29 Ntest
# 2 != 1
# SNRdb = 3 | 18 Nerr | 31 Ntest
# 9 != 8
# SNRdb = 3 | 19 Nerr | 32 Ntest
# 6 != 7
# SNRdb = 3 | 20 Nerr | 33 Ntest
# 15 != 8
# SNRdb = 3 | 21 Nerr | 35 Ntest
# 10 != 2
# SNRdb = 3 | 22 Nerr | 36 Ntest
# 1 != 7
# SNRdb = 3 | 23 Nerr | 40 Ntest
# 8 != 1
# SNRdb = 3 | 24 Nerr | 42 Ntest
# 11 != 5
# SNRdb = 3 | 25 Nerr | 43 Ntest
# 6 != 4
# SNRdb = 3 | 26 Nerr | 44 Ntest
# 2 != 8
# SNRdb = 3 | 27 Nerr | 45 Ntest
# 10 != 4
# SNRdb = 3 | 28 Nerr | 54 Ntest
# 11 != 4
# SNRdb = 3 | 29 Nerr | 57 Ntest
# 4 != 0
# SNRdb = 3 | 30 Nerr | 58 Ntest
# 0 != 12
# SNRdb = 3 | 31 Nerr | 60 Ntest
# 10 != 8
# SNRdb = 3 | 32 Nerr | 62 Ntest
# 6 != 14
# SNRdb = 3 | 33 Nerr | 63 Ntest
# 1 != 3
# SNRdb = 3 | 34 Nerr | 70 Ntest
# 0 != 4
# SNRdb = 3 | 35 Nerr | 71 Ntest
# 9 != 13
# SNRdb = 3 | 36 Nerr | 73 Ntest
# 11 != 1
# SNRdb = 3 | 37 Nerr | 74 Ntest
# 10 != 12
# SNRdb = 3 | 38 Nerr | 79 Ntest
# 14 != 4
# SNRdb = 3 | 39 Nerr | 80 Ntest
# 15 != 13
# SNRdb = 3 | 40 Nerr | 81 Ntest
# 6 != 15
# SNRdb = 3 | 41 Nerr | 82 Ntest
# 15 != 3
# SNRdb = 3 | 42 Nerr | 83 Ntest
# 5 != 12
# SNRdb = 3 | 43 Nerr | 84 Ntest
# 2 != 10
# SNRdb = 3 | 44 Nerr | 86 Ntest
# 8 != 2
# SNRdb = 3 | 45 Nerr | 89 Ntest
# 15 != 5
# SNRdb = 3 | 46 Nerr | 92 Ntest
# 2 != 6
# SNRdb = 3 | 47 Nerr | 93 Ntest
# 10 != 1
# SNRdb = 3 | 48 Nerr | 94 Ntest
# 15 != 2
# SNRdb = 3 | 49 Nerr | 95 Ntest
# 10 != 14
# SNRdb = 3 | 50 Nerr | 96 Ntest
# Pe 0.5154639175257731
# 2 != 8
# SNRdb = 4 | 1 Nerr | 0 Ntest
# 1 != 5
# SNRdb = 4 | 2 Nerr | 2 Ntest
# 1 != 6
# SNRdb = 4 | 3 Nerr | 3 Ntest
# 0 != 10
# SNRdb = 4 | 4 Nerr | 6 Ntest
# 0 != 13
# SNRdb = 4 | 5 Nerr | 7 Ntest
# 5 != 9
# SNRdb = 4 | 6 Nerr | 8 Ntest
# 1 != 9
# SNRdb = 4 | 7 Nerr | 9 Ntest
# 12 != 9
# SNRdb = 4 | 8 Nerr | 10 Ntest
# 7 != 14
# SNRdb = 4 | 9 Nerr | 11 Ntest
# 13 != 15
# SNRdb = 4 | 10 Nerr | 14 Ntest
# 9 != 13
# SNRdb = 4 | 11 Nerr | 16 Ntest
# 8 != 6
# SNRdb = 4 | 12 Nerr | 17 Ntest
# 13 != 12
# SNRdb = 4 | 13 Nerr | 18 Ntest
# 13 != 15
# SNRdb = 4 | 14 Nerr | 19 Ntest
# 9 != 11
# SNRdb = 4 | 15 Nerr | 20 Ntest
# 7 != 5
# SNRdb = 4 | 16 Nerr | 21 Ntest
# 10 != 1
# SNRdb = 4 | 17 Nerr | 22 Ntest
# 8 != 9
# SNRdb = 4 | 18 Nerr | 23 Ntest
# 4 != 13
# SNRdb = 4 | 19 Nerr | 24 Ntest
# 11 != 2
# SNRdb = 4 | 20 Nerr | 25 Ntest
# 6 != 9
# SNRdb = 4 | 21 Nerr | 26 Ntest
# 4 != 5
# SNRdb = 4 | 22 Nerr | 29 Ntest
# 11 != 2
# SNRdb = 4 | 23 Nerr | 30 Ntest
# 14 != 6
# SNRdb = 4 | 24 Nerr | 31 Ntest
# 1 != 2
# SNRdb = 4 | 25 Nerr | 32 Ntest
# 8 != 10
# SNRdb = 4 | 26 Nerr | 35 Ntest
# 14 != 6
# SNRdb = 4 | 27 Nerr | 36 Ntest
# 11 != 5
# SNRdb = 4 | 28 Nerr | 37 Ntest
# 13 != 1
# SNRdb = 4 | 29 Nerr | 38 Ntest
# 10 != 15
# SNRdb = 4 | 30 Nerr | 42 Ntest
# 12 != 10
# SNRdb = 4 | 31 Nerr | 43 Ntest
# 9 != 3
# SNRdb = 4 | 32 Nerr | 44 Ntest
# 8 != 15
# SNRdb = 4 | 33 Nerr | 45 Ntest
# 15 != 14
# SNRdb = 4 | 34 Nerr | 47 Ntest
# 9 != 1
# SNRdb = 4 | 35 Nerr | 48 Ntest
# 3 != 5
# SNRdb = 4 | 36 Nerr | 49 Ntest
# 15 != 1
# SNRdb = 4 | 37 Nerr | 53 Ntest
# 6 != 13
# SNRdb = 4 | 38 Nerr | 55 Ntest
# 6 != 3
# SNRdb = 4 | 39 Nerr | 56 Ntest
# 5 != 4
# SNRdb = 4 | 40 Nerr | 57 Ntest
# 8 != 10
# SNRdb = 4 | 41 Nerr | 58 Ntest
# 5 != 2
# SNRdb = 4 | 42 Nerr | 60 Ntest
# 5 != 14
# SNRdb = 4 | 43 Nerr | 61 Ntest
# 15 != 6
# SNRdb = 4 | 44 Nerr | 62 Ntest
# 9 != 13
# SNRdb = 4 | 45 Nerr | 65 Ntest
# 12 != 15
# SNRdb = 4 | 46 Nerr | 68 Ntest
# 6 != 9
# SNRdb = 4 | 47 Nerr | 70 Ntest
# 0 != 12
# SNRdb = 4 | 48 Nerr | 71 Ntest
# 1 != 8
# SNRdb = 4 | 49 Nerr | 80 Ntest
# 2 != 9
# SNRdb = 4 | 50 Nerr | 81 Ntest
# Pe 0.6097560975609756
# 11 != 15
# SNRdb = 5 | 1 Nerr | 0 Ntest
# 15 != 12
# SNRdb = 5 | 2 Nerr | 1 Ntest
# 7 != 13
# SNRdb = 5 | 3 Nerr | 3 Ntest
# 4 != 0
# SNRdb = 5 | 4 Nerr | 4 Ntest
# 7 != 6
# SNRdb = 5 | 5 Nerr | 5 Ntest
# 0 != 1
# SNRdb = 5 | 6 Nerr | 7 Ntest
# 5 != 8
# SNRdb = 5 | 7 Nerr | 8 Ntest
# 6 != 13
# SNRdb = 5 | 8 Nerr | 9 Ntest
# 5 != 13
# SNRdb = 5 | 9 Nerr | 13 Ntest
# 12 != 4
# SNRdb = 5 | 10 Nerr | 14 Ntest
# 8 != 1
# SNRdb = 5 | 11 Nerr | 20 Ntest
# 11 != 15
# SNRdb = 5 | 12 Nerr | 21 Ntest
# 10 != 7
# SNRdb = 5 | 13 Nerr | 22 Ntest
# 15 != 11
# SNRdb = 5 | 14 Nerr | 24 Ntest
# 6 != 15
# SNRdb = 5 | 15 Nerr | 27 Ntest
# 6 != 4
# SNRdb = 5 | 16 Nerr | 29 Ntest
# 14 != 9
# SNRdb = 5 | 17 Nerr | 38 Ntest
# 4 != 6
# SNRdb = 5 | 18 Nerr | 39 Ntest
# 14 != 1
# SNRdb = 5 | 19 Nerr | 40 Ntest
# 9 != 13
# SNRdb = 5 | 20 Nerr | 44 Ntest
# 7 != 5
# SNRdb = 5 | 21 Nerr | 45 Ntest
# 9 != 4
# SNRdb = 5 | 22 Nerr | 48 Ntest
# 1 != 14
# SNRdb = 5 | 23 Nerr | 50 Ntest
# 6 != 4
# SNRdb = 5 | 24 Nerr | 51 Ntest
# 15 != 2
# SNRdb = 5 | 25 Nerr | 53 Ntest
# 7 != 15
# SNRdb = 5 | 26 Nerr | 55 Ntest
# 10 != 0
# SNRdb = 5 | 27 Nerr | 60 Ntest
# 12 != 10
# SNRdb = 5 | 28 Nerr | 62 Ntest
# 7 != 9
# SNRdb = 5 | 29 Nerr | 65 Ntest
# 3 != 7
# SNRdb = 5 | 30 Nerr | 68 Ntest
# 3 != 0
# SNRdb = 5 | 31 Nerr | 69 Ntest
# 6 != 0
# SNRdb = 5 | 32 Nerr | 70 Ntest
# 5 != 11
# SNRdb = 5 | 33 Nerr | 72 Ntest
# 15 != 9
# SNRdb = 5 | 34 Nerr | 74 Ntest
# 2 != 0
# SNRdb = 5 | 35 Nerr | 75 Ntest
# 6 != 5
# SNRdb = 5 | 36 Nerr | 76 Ntest
# 15 != 9
# SNRdb = 5 | 37 Nerr | 78 Ntest
# 1 != 11
# SNRdb = 5 | 38 Nerr | 80 Ntest
# 6 != 0
# SNRdb = 5 | 39 Nerr | 84 Ntest
# 11 != 13
# SNRdb = 5 | 40 Nerr | 87 Ntest
# 10 != 15
# SNRdb = 5 | 41 Nerr | 88 Ntest
# 14 != 15
# SNRdb = 5 | 42 Nerr | 91 Ntest
# 14 != 8
# SNRdb = 5 | 43 Nerr | 94 Ntest
# 1 != 15
# SNRdb = 5 | 44 Nerr | 97 Ntest
# 5 != 9
# SNRdb = 5 | 45 Nerr | 98 Ntest
# 11 != 10
# SNRdb = 5 | 46 Nerr | 99 Ntest
# 7 != 13
# SNRdb = 5 | 47 Nerr | 103 Ntest
# 13 != 4
# SNRdb = 5 | 48 Nerr | 104 Ntest
# 9 != 1
# SNRdb = 5 | 49 Nerr | 107 Ntest
# 10 != 15
# SNRdb = 5 | 50 Nerr | 111 Ntest
# Pe 0.44642857142857145
# 8 != 2
# SNRdb = 6 | 1 Nerr | 2 Ntest
# 8 != 15
# SNRdb = 6 | 2 Nerr | 4 Ntest
# 8 != 7
# SNRdb = 6 | 3 Nerr | 5 Ntest
# 9 != 11
# SNRdb = 6 | 4 Nerr | 9 Ntest
# 9 != 3
# SNRdb = 6 | 5 Nerr | 11 Ntest
# 2 != 1
# SNRdb = 6 | 6 Nerr | 12 Ntest
# 5 != 8
# SNRdb = 6 | 7 Nerr | 13 Ntest
# 10 != 15
# SNRdb = 6 | 8 Nerr | 14 Ntest
# 5 != 3
# SNRdb = 6 | 9 Nerr | 18 Ntest
# 15 != 2
# SNRdb = 6 | 10 Nerr | 19 Ntest
# 15 != 13
# SNRdb = 6 | 11 Nerr | 25 Ntest
# 0 != 11
# SNRdb = 6 | 12 Nerr | 27 Ntest
# 3 != 13
# SNRdb = 6 | 13 Nerr | 28 Ntest
# 8 != 13
# SNRdb = 6 | 14 Nerr | 29 Ntest
# 8 != 15
# SNRdb = 6 | 15 Nerr | 38 Ntest
# 9 != 5
# SNRdb = 6 | 16 Nerr | 42 Ntest
# 11 != 10
# SNRdb = 6 | 17 Nerr | 49 Ntest
# 1 != 5
# SNRdb = 6 | 18 Nerr | 54 Ntest
# 12 != 4
# SNRdb = 6 | 19 Nerr | 56 Ntest
# 9 != 3
# SNRdb = 6 | 20 Nerr | 62 Ntest
# 2 != 15
# SNRdb = 6 | 21 Nerr | 63 Ntest
# 7 != 0
# SNRdb = 6 | 22 Nerr | 64 Ntest
# 12 != 5
# SNRdb = 6 | 23 Nerr | 68 Ntest
# 11 != 2
# SNRdb = 6 | 24 Nerr | 69 Ntest
# 9 != 13
# SNRdb = 6 | 25 Nerr | 72 Ntest
# 0 != 13
# SNRdb = 6 | 26 Nerr | 74 Ntest
# 5 != 2
# SNRdb = 6 | 27 Nerr | 78 Ntest
# 4 != 15
# SNRdb = 6 | 28 Nerr | 83 Ntest
# 11 != 14
# SNRdb = 6 | 29 Nerr | 85 Ntest
# 9 != 12
# SNRdb = 6 | 30 Nerr | 86 Ntest
# 11 != 12
# SNRdb = 6 | 31 Nerr | 89 Ntest
# 12 != 3
# SNRdb = 6 | 32 Nerr | 90 Ntest
# 14 != 6
# SNRdb = 6 | 33 Nerr | 94 Ntest
# 13 != 6
# SNRdb = 6 | 34 Nerr | 96 Ntest
# 4 != 12
# SNRdb = 6 | 35 Nerr | 98 Ntest
# 4 != 8
# SNRdb = 6 | 36 Nerr | 100 Ntest
# 10 != 3
# SNRdb = 6 | 37 Nerr | 104 Ntest
# 11 != 12
# SNRdb = 6 | 38 Nerr | 107 Ntest
# 1 != 8
# SNRdb = 6 | 39 Nerr | 109 Ntest
# 14 != 4
# SNRdb = 6 | 40 Nerr | 110 Ntest
# 14 != 4
# SNRdb = 6 | 41 Nerr | 115 Ntest
# 4 != 2
# SNRdb = 6 | 42 Nerr | 120 Ntest
# 13 != 2
# SNRdb = 6 | 43 Nerr | 124 Ntest
# 7 != 11
# SNRdb = 6 | 44 Nerr | 126 Ntest
# 1 != 13
# SNRdb = 6 | 45 Nerr | 137 Ntest
# 15 != 13
# SNRdb = 6 | 46 Nerr | 139 Ntest
# 8 != 9
# SNRdb = 6 | 47 Nerr | 142 Ntest
# 2 != 9
# SNRdb = 6 | 48 Nerr | 143 Ntest
# 12 != 3
# SNRdb = 6 | 49 Nerr | 144 Ntest
# 4 != 6
# SNRdb = 6 | 50 Nerr | 145 Ntest
# Pe 0.3424657534246575
# 5 != 7
# SNRdb = 7 | 1 Nerr | 2 Ntest
# 10 != 12
# SNRdb = 7 | 2 Nerr | 3 Ntest
# 3 != 10
# SNRdb = 7 | 3 Nerr | 4 Ntest
# 10 != 12
# SNRdb = 7 | 4 Nerr | 11 Ntest
# 7 != 6
# SNRdb = 7 | 5 Nerr | 15 Ntest
# 11 != 2
# SNRdb = 7 | 6 Nerr | 19 Ntest
# 6 != 14
# SNRdb = 7 | 7 Nerr | 23 Ntest
# 14 != 8
# SNRdb = 7 | 8 Nerr | 24 Ntest
# 6 != 9
# SNRdb = 7 | 9 Nerr | 25 Ntest
# 8 != 10
# SNRdb = 7 | 10 Nerr | 26 Ntest
# 0 != 13
# SNRdb = 7 | 11 Nerr | 27 Ntest
# 4 != 3
# SNRdb = 7 | 12 Nerr | 33 Ntest
# 13 != 15
# SNRdb = 7 | 13 Nerr | 38 Ntest
# 13 != 4
# SNRdb = 7 | 14 Nerr | 42 Ntest
# 11 != 5
# SNRdb = 7 | 15 Nerr | 43 Ntest
# 3 != 9
# SNRdb = 7 | 16 Nerr | 44 Ntest
# 1 != 15
# SNRdb = 7 | 17 Nerr | 48 Ntest
# 10 != 3
# SNRdb = 7 | 18 Nerr | 50 Ntest
# 0 != 10
# SNRdb = 7 | 19 Nerr | 59 Ntest
# 15 != 2
# SNRdb = 7 | 20 Nerr | 63 Ntest
# 1 != 8
# SNRdb = 7 | 21 Nerr | 65 Ntest
# 5 != 12
# SNRdb = 7 | 22 Nerr | 68 Ntest
# 11 != 1
# SNRdb = 7 | 23 Nerr | 71 Ntest
# 5 != 12
# SNRdb = 7 | 24 Nerr | 73 Ntest
# 13 != 4
# SNRdb = 7 | 25 Nerr | 74 Ntest
# 6 != 0
# SNRdb = 7 | 26 Nerr | 79 Ntest
# 7 != 10
# SNRdb = 7 | 27 Nerr | 96 Ntest
# 9 != 14
# SNRdb = 7 | 28 Nerr | 102 Ntest
# 2 != 4
# SNRdb = 7 | 29 Nerr | 104 Ntest
# 4 != 14
# SNRdb = 7 | 30 Nerr | 115 Ntest
# 14 != 1
# SNRdb = 7 | 31 Nerr | 121 Ntest
# 4 != 7
# SNRdb = 7 | 32 Nerr | 123 Ntest
# 4 != 14
# SNRdb = 7 | 33 Nerr | 124 Ntest
# 8 != 4
# SNRdb = 7 | 34 Nerr | 125 Ntest
# 6 != 0
# SNRdb = 7 | 35 Nerr | 126 Ntest
# 9 != 6
# SNRdb = 7 | 36 Nerr | 130 Ntest
# 9 != 7
# SNRdb = 7 | 37 Nerr | 147 Ntest
# 15 != 13
# SNRdb = 7 | 38 Nerr | 159 Ntest
# 5 != 2
# SNRdb = 7 | 39 Nerr | 167 Ntest
# 12 != 14
# SNRdb = 7 | 40 Nerr | 169 Ntest
# 10 != 11
# SNRdb = 7 | 41 Nerr | 170 Ntest
# 11 != 8
# SNRdb = 7 | 42 Nerr | 171 Ntest
# 4 != 9
# SNRdb = 7 | 43 Nerr | 174 Ntest
# 0 != 3
# SNRdb = 7 | 44 Nerr | 179 Ntest
# 3 != 1
# SNRdb = 7 | 45 Nerr | 180 Ntest
# 6 != 11
# SNRdb = 7 | 46 Nerr | 187 Ntest
# 10 != 8
# SNRdb = 7 | 47 Nerr | 192 Ntest
# 7 != 6
# SNRdb = 7 | 48 Nerr | 193 Ntest
# 1 != 15
# SNRdb = 7 | 49 Nerr | 198 Ntest
# 0 != 10
# SNRdb = 7 | 50 Nerr | 199 Ntest
# Pe 0.25
# 6 != 2
# SNRdb = 8 | 1 Nerr | 14 Ntest
# 3 != 7
# SNRdb = 8 | 2 Nerr | 32 Ntest
# 7 != 8
# SNRdb = 8 | 3 Nerr | 36 Ntest
# 4 != 7
# SNRdb = 8 | 4 Nerr | 38 Ntest
# 13 != 5
# SNRdb = 8 | 5 Nerr | 47 Ntest
# 12 != 1
# SNRdb = 8 | 6 Nerr | 55 Ntest
# 9 != 7
# SNRdb = 8 | 7 Nerr | 57 Ntest
# 8 != 0
# SNRdb = 8 | 8 Nerr | 59 Ntest
# 2 != 11
# SNRdb = 8 | 9 Nerr | 66 Ntest
# 10 != 11
# SNRdb = 8 | 10 Nerr | 73 Ntest
# 2 != 7
# SNRdb = 8 | 11 Nerr | 87 Ntest
# 12 != 11
# SNRdb = 8 | 12 Nerr | 91 Ntest
# 13 != 12
# SNRdb = 8 | 13 Nerr | 104 Ntest
# 6 != 12
# SNRdb = 8 | 14 Nerr | 105 Ntest
# 11 != 8
# SNRdb = 8 | 15 Nerr | 109 Ntest
# 10 != 12
# SNRdb = 8 | 16 Nerr | 118 Ntest
# 2 != 3
# SNRdb = 8 | 17 Nerr | 136 Ntest
# 14 != 10
# SNRdb = 8 | 18 Nerr | 140 Ntest
# 12 != 3
# SNRdb = 8 | 19 Nerr | 144 Ntest
# 3 != 13
# SNRdb = 8 | 20 Nerr | 157 Ntest
# 8 != 11
# SNRdb = 8 | 21 Nerr | 163 Ntest
# 13 != 7
# SNRdb = 8 | 22 Nerr | 167 Ntest
# 15 != 10
# SNRdb = 8 | 23 Nerr | 168 Ntest
# 7 != 14
# SNRdb = 8 | 24 Nerr | 176 Ntest
# 3 != 1
# SNRdb = 8 | 25 Nerr | 191 Ntest
# 10 != 6
# SNRdb = 8 | 26 Nerr | 212 Ntest
# 10 != 8
# SNRdb = 8 | 27 Nerr | 213 Ntest
# 1 != 12
# SNRdb = 8 | 28 Nerr | 227 Ntest
# 2 != 8
# SNRdb = 8 | 29 Nerr | 228 Ntest
# 10 != 9
# SNRdb = 8 | 30 Nerr | 230 Ntest
# 11 != 10
# SNRdb = 8 | 31 Nerr | 237 Ntest
# 15 != 11
# SNRdb = 8 | 32 Nerr | 247 Ntest
# 5 != 7
# SNRdb = 8 | 33 Nerr | 255 Ntest
# 1 != 2
# SNRdb = 8 | 34 Nerr | 256 Ntest
# 14 != 3
# SNRdb = 8 | 35 Nerr | 267 Ntest
# 9 != 0
# SNRdb = 8 | 36 Nerr | 274 Ntest
# 10 != 0
# SNRdb = 8 | 37 Nerr | 280 Ntest
# 6 != 7
# SNRdb = 8 | 38 Nerr | 284 Ntest
# 14 != 15
# SNRdb = 8 | 39 Nerr | 294 Ntest
# 10 != 12
# SNRdb = 8 | 40 Nerr | 295 Ntest
# 9 != 0
# SNRdb = 8 | 41 Nerr | 298 Ntest
# 11 != 8
# SNRdb = 8 | 42 Nerr | 301 Ntest
# 7 != 0
# SNRdb = 8 | 43 Nerr | 303 Ntest
# 1 != 11
# SNRdb = 8 | 44 Nerr | 315 Ntest
# 15 != 1
# SNRdb = 8 | 45 Nerr | 323 Ntest
# 15 != 8
# SNRdb = 8 | 46 Nerr | 343 Ntest
# 2 != 7
# SNRdb = 8 | 47 Nerr | 348 Ntest
# 11 != 13
# SNRdb = 8 | 48 Nerr | 349 Ntest
# 5 != 12
# SNRdb = 8 | 49 Nerr | 357 Ntest
# 13 != 1
# SNRdb = 8 | 50 Nerr | 358 Ntest
# Pe 0.1392757660167131
# 0 != 14
# SNRdb = 9 | 1 Nerr | 18 Ntest
# 9 != 1
# SNRdb = 9 | 2 Nerr | 33 Ntest
# 9 != 6
# SNRdb = 9 | 3 Nerr | 40 Ntest
# 2 != 5
# SNRdb = 9 | 4 Nerr | 46 Ntest
# 11 != 2
# SNRdb = 9 | 5 Nerr | 50 Ntest
# 3 != 8
# SNRdb = 9 | 6 Nerr | 66 Ntest
# 0 != 5
# SNRdb = 9 | 7 Nerr | 98 Ntest
# 5 != 3
# SNRdb = 9 | 8 Nerr | 101 Ntest
# 14 != 4
# SNRdb = 9 | 9 Nerr | 111 Ntest
# 15 != 5
# SNRdb = 9 | 10 Nerr | 112 Ntest
# 13 != 14
# SNRdb = 9 | 11 Nerr | 124 Ntest
# 11 != 5
# SNRdb = 9 | 12 Nerr | 125 Ntest
# 8 != 2
# SNRdb = 9 | 13 Nerr | 129 Ntest
# 2 != 8
# SNRdb = 9 | 14 Nerr | 143 Ntest
# 7 != 2
# SNRdb = 9 | 15 Nerr | 148 Ntest
# 10 != 1
# SNRdb = 9 | 16 Nerr | 190 Ntest
# 3 != 10
# SNRdb = 9 | 17 Nerr | 230 Ntest
# 5 != 14
# SNRdb = 9 | 18 Nerr | 263 Ntest
# 11 != 7
# SNRdb = 9 | 19 Nerr | 266 Ntest
# 14 != 12
# SNRdb = 9 | 20 Nerr | 271 Ntest
# 10 != 15
# SNRdb = 9 | 21 Nerr | 279 Ntest
# 4 != 12
# SNRdb = 9 | 22 Nerr | 282 Ntest
# 1 != 8
# SNRdb = 9 | 23 Nerr | 291 Ntest
# 15 != 4
# SNRdb = 9 | 24 Nerr | 292 Ntest
# 15 != 8
# SNRdb = 9 | 25 Nerr | 296 Ntest
# 8 != 10
# SNRdb = 9 | 26 Nerr | 303 Ntest
# 6 != 5
# SNRdb = 9 | 27 Nerr | 307 Ntest
# 5 != 6
# SNRdb = 9 | 28 Nerr | 316 Ntest
# 10 != 2
# SNRdb = 9 | 29 Nerr | 321 Ntest
# 0 != 13
# SNRdb = 9 | 30 Nerr | 327 Ntest
# 8 != 4
# SNRdb = 9 | 31 Nerr | 345 Ntest
# 8 != 14
# SNRdb = 9 | 32 Nerr | 365 Ntest
# 11 != 0
# SNRdb = 9 | 33 Nerr | 375 Ntest
# 0 != 7
# SNRdb = 9 | 34 Nerr | 378 Ntest
# 6 != 13
# SNRdb = 9 | 35 Nerr | 383 Ntest
# 11 != 2
# SNRdb = 9 | 36 Nerr | 397 Ntest
# 5 != 13
# SNRdb = 9 | 37 Nerr | 410 Ntest
# 8 != 3
# SNRdb = 9 | 38 Nerr | 414 Ntest
# 6 != 13
# SNRdb = 9 | 39 Nerr | 422 Ntest
# 2 != 14
# SNRdb = 9 | 40 Nerr | 442 Ntest
# 11 != 14
# SNRdb = 9 | 41 Nerr | 447 Ntest
# 9 != 7
# SNRdb = 9 | 42 Nerr | 450 Ntest
# 5 != 3
# SNRdb = 9 | 43 Nerr | 462 Ntest
# 14 != 4
# SNRdb = 9 | 44 Nerr | 478 Ntest
# 10 != 11
# SNRdb = 9 | 45 Nerr | 490 Ntest
# 9 != 3
# SNRdb = 9 | 46 Nerr | 491 Ntest
# 8 != 3
# SNRdb = 9 | 47 Nerr | 500 Ntest
# 6 != 8
# SNRdb = 9 | 48 Nerr | 501 Ntest
# 4 != 13
# SNRdb = 9 | 49 Nerr | 504 Ntest
# 15 != 9
# SNRdb = 9 | 50 Nerr | 549 Ntest
# Pe 0.09090909090909091
# 3 != 5
# SNRdb = 10 | 1 Nerr | 19 Ntest
# 12 != 2
# SNRdb = 10 | 2 Nerr | 71 Ntest
# 10 != 8
# SNRdb = 10 | 3 Nerr | 143 Ntest
# 8 != 3
# SNRdb = 10 | 4 Nerr | 144 Ntest
# 0 != 6
# SNRdb = 10 | 5 Nerr | 191 Ntest
# 12 != 15
# SNRdb = 10 | 6 Nerr | 212 Ntest
# 8 != 5
# SNRdb = 10 | 7 Nerr | 274 Ntest
# 5 != 8
# SNRdb = 10 | 8 Nerr | 410 Ntest
# 14 != 9
# SNRdb = 10 | 9 Nerr | 494 Ntest
# 8 != 15
# SNRdb = 10 | 10 Nerr | 501 Ntest
# 11 != 7
# SNRdb = 10 | 11 Nerr | 502 Ntest
# 1 != 8
# SNRdb = 10 | 12 Nerr | 503 Ntest
# 9 != 6
# SNRdb = 10 | 13 Nerr | 540 Ntest
# 7 != 13
# SNRdb = 10 | 14 Nerr | 577 Ntest
# 1 != 13
# SNRdb = 10 | 15 Nerr | 588 Ntest
# 0 != 1
# SNRdb = 10 | 16 Nerr | 600 Ntest
# 13 != 1
# SNRdb = 10 | 17 Nerr | 646 Ntest
# 6 != 5
# SNRdb = 10 | 18 Nerr | 667 Ntest
# 0 != 11
# SNRdb = 10 | 19 Nerr | 871 Ntest
# 14 != 8
# SNRdb = 10 | 20 Nerr | 878 Ntest
# 0 != 4
# SNRdb = 10 | 21 Nerr | 893 Ntest
# 15 != 3
# SNRdb = 10 | 22 Nerr | 961 Ntest
# 14 != 15
# SNRdb = 10 | 23 Nerr | 988 Ntest
# 11 != 7
# SNRdb = 10 | 24 Nerr | 1003 Ntest
# 11 != 8
# SNRdb = 10 | 25 Nerr | 1008 Ntest
# 6 != 5
# SNRdb = 10 | 26 Nerr | 1009 Ntest
# 5 != 9
# SNRdb = 10 | 27 Nerr | 1013 Ntest
# 4 != 11
# SNRdb = 10 | 28 Nerr | 1015 Ntest
# 13 != 9
# SNRdb = 10 | 29 Nerr | 1026 Ntest
# 11 != 7
# SNRdb = 10 | 30 Nerr | 1034 Ntest
# 3 != 15
# SNRdb = 10 | 31 Nerr | 1065 Ntest
# 12 != 7
# SNRdb = 10 | 32 Nerr | 1091 Ntest
# 12 != 1
# SNRdb = 10 | 33 Nerr | 1140 Ntest
# 4 != 0
# SNRdb = 10 | 34 Nerr | 1196 Ntest
# 14 != 4
# SNRdb = 10 | 35 Nerr | 1221 Ntest
# 15 != 3
# SNRdb = 10 | 36 Nerr | 1246 Ntest
# 2 != 3
# SNRdb = 10 | 37 Nerr | 1265 Ntest
# 10 != 9
# SNRdb = 10 | 38 Nerr | 1341 Ntest
# 2 != 6
# SNRdb = 10 | 39 Nerr | 1444 Ntest
# 0 != 4
# SNRdb = 10 | 40 Nerr | 1464 Ntest
# 10 != 5
# SNRdb = 10 | 41 Nerr | 1469 Ntest
# 4 != 0
# SNRdb = 10 | 42 Nerr | 1487 Ntest
# 1 != 14
# SNRdb = 10 | 43 Nerr | 1523 Ntest
# 5 != 8
# SNRdb = 10 | 44 Nerr | 1663 Ntest
# 11 != 12
# SNRdb = 10 | 45 Nerr | 1717 Ntest
# 4 != 6
# SNRdb = 10 | 46 Nerr | 1720 Ntest
# 0 != 7
# SNRdb = 10 | 47 Nerr | 1789 Ntest
# 1 != 11
# SNRdb = 10 | 48 Nerr | 1798 Ntest
# 4 != 0
# SNRdb = 10 | 49 Nerr | 1803 Ntest
# 14 != 5
# SNRdb = 10 | 50 Nerr | 1846 Ntest
# Pe 0.02707092582566324
# 9 != 13
# SNRdb = 11 | 1 Nerr | 37 Ntest
# 4 != 5
# SNRdb = 11 | 2 Nerr | 89 Ntest
# 3 != 8
# SNRdb = 11 | 3 Nerr | 393 Ntest
# 15 != 11
# SNRdb = 11 | 4 Nerr | 421 Ntest
# 7 != 15
# SNRdb = 11 | 5 Nerr | 467 Ntest
# 5 != 13
# SNRdb = 11 | 6 Nerr | 679 Ntest
# 3 != 6
# SNRdb = 11 | 7 Nerr | 973 Ntest
# 1 != 5
# SNRdb = 11 | 8 Nerr | 1006 Ntest
# 5 != 3
# SNRdb = 11 | 9 Nerr | 1176 Ntest
# 15 != 13
# SNRdb = 11 | 10 Nerr | 1189 Ntest
# 8 != 1
# SNRdb = 11 | 11 Nerr | 1284 Ntest
# 5 != 14
# SNRdb = 11 | 12 Nerr | 1307 Ntest
# 13 != 10
# SNRdb = 11 | 13 Nerr | 1418 Ntest
# 10 != 15
# SNRdb = 11 | 14 Nerr | 1474 Ntest
# 8 != 3
# SNRdb = 11 | 15 Nerr | 1808 Ntest
# 15 != 1
# SNRdb = 11 | 16 Nerr | 2032 Ntest
# 2 != 15
# SNRdb = 11 | 17 Nerr | 2064 Ntest
# 14 != 8
# SNRdb = 11 | 18 Nerr | 2065 Ntest
# 7 != 15
# SNRdb = 11 | 19 Nerr | 2122 Ntest
# 13 != 0
# SNRdb = 11 | 20 Nerr | 2181 Ntest
# 3 != 11
# SNRdb = 11 | 21 Nerr | 2226 Ntest
# 3 != 12
# SNRdb = 11 | 22 Nerr | 2238 Ntest
# 0 != 11
# SNRdb = 11 | 23 Nerr | 2265 Ntest
# 12 != 3
# SNRdb = 11 | 24 Nerr | 2300 Ntest
# 0 != 14
# SNRdb = 11 | 25 Nerr | 2394 Ntest
# 14 != 9
# SNRdb = 11 | 26 Nerr | 2405 Ntest
# 8 != 6
# SNRdb = 11 | 27 Nerr | 2442 Ntest
# 12 != 13
# SNRdb = 11 | 28 Nerr | 2457 Ntest
# 5 != 11
# SNRdb = 11 | 29 Nerr | 2539 Ntest
# 5 != 13
# SNRdb = 11 | 30 Nerr | 2572 Ntest
# 9 != 0
# SNRdb = 11 | 31 Nerr | 2729 Ntest
# 3 != 12
# SNRdb = 11 | 32 Nerr | 3024 Ntest
# 5 != 4
# SNRdb = 11 | 33 Nerr | 3118 Ntest
# 0 != 10
# SNRdb = 11 | 34 Nerr | 3162 Ntest
# 9 != 12
# SNRdb = 11 | 35 Nerr | 3247 Ntest
# 13 != 6
# SNRdb = 11 | 36 Nerr | 3488 Ntest
# 0 != 5
# SNRdb = 11 | 37 Nerr | 3527 Ntest
# 3 != 4
# SNRdb = 11 | 38 Nerr | 3574 Ntest
# 5 != 12
# SNRdb = 11 | 39 Nerr | 3759 Ntest
# 13 != 11
# SNRdb = 11 | 40 Nerr | 3865 Ntest
# 15 != 4
# SNRdb = 11 | 41 Nerr | 3873 Ntest
# 12 != 13
# SNRdb = 11 | 42 Nerr | 3898 Ntest
# 2 != 10
# SNRdb = 11 | 43 Nerr | 3932 Ntest
# 3 != 5
# SNRdb = 11 | 44 Nerr | 3967 Ntest
# 0 != 2
# SNRdb = 11 | 45 Nerr | 4112 Ntest
# 9 != 3
# SNRdb = 11 | 46 Nerr | 4184 Ntest
# 1 != 3
# SNRdb = 11 | 47 Nerr | 4241 Ntest
# 4 != 2
# SNRdb = 11 | 48 Nerr | 4838 Ntest
# 1 != 14
# SNRdb = 11 | 49 Nerr | 4848 Ntest
# 11 != 9
# SNRdb = 11 | 50 Nerr | 4946 Ntest
# Pe 0.01010713563776026
# 0 != 3
# SNRdb = 12 | 1 Nerr | 153 Ntest
# 0 != 5
# SNRdb = 12 | 2 Nerr | 354 Ntest
# 11 != 14
# SNRdb = 12 | 3 Nerr | 1328 Ntest
# 9 != 12
# SNRdb = 12 | 4 Nerr | 1418 Ntest
# 4 != 15
# SNRdb = 12 | 5 Nerr | 1439 Ntest
# 12 != 15
# SNRdb = 12 | 6 Nerr | 1669 Ntest
# 1 != 3
# SNRdb = 12 | 7 Nerr | 1836 Ntest
# 1 != 9
# SNRdb = 12 | 8 Nerr | 2078 Ntest
# 8 != 11
# SNRdb = 12 | 9 Nerr | 3201 Ntest
# 12 != 10
# SNRdb = 12 | 10 Nerr | 3690 Ntest
# 5 != 13
# SNRdb = 12 | 11 Nerr | 3775 Ntest
# 3 != 11
# SNRdb = 12 | 12 Nerr | 4567 Ntest
# 7 != 11
# SNRdb = 12 | 13 Nerr | 6105 Ntest
# 15 != 12
# SNRdb = 12 | 14 Nerr | 7024 Ntest
# 2 != 11
# SNRdb = 12 | 15 Nerr | 9732 Ntest
# 7 != 3
# SNRdb = 12 | 16 Nerr | 10254 Ntest
# 11 != 5
# SNRdb = 12 | 17 Nerr | 10685 Ntest
# 15 != 10
# SNRdb = 12 | 18 Nerr | 10728 Ntest
# 15 != 3
# SNRdb = 12 | 19 Nerr | 11259 Ntest
# 2 != 6
# SNRdb = 12 | 20 Nerr | 12181 Ntest
# 14 != 3
# SNRdb = 12 | 21 Nerr | 12429 Ntest
# 7 != 11
# SNRdb = 12 | 22 Nerr | 12552 Ntest
# 12 != 4
# SNRdb = 12 | 23 Nerr | 14429 Ntest
# 11 != 12
# SNRdb = 12 | 24 Nerr | 14763 Ntest
# 1 != 7
# SNRdb = 12 | 25 Nerr | 14801 Ntest
# 6 != 13
# SNRdb = 12 | 26 Nerr | 14892 Ntest
# 5 != 10
# SNRdb = 12 | 27 Nerr | 15062 Ntest
# 9 != 3
# SNRdb = 12 | 28 Nerr | 15671 Ntest
# 12 != 6
# SNRdb = 12 | 29 Nerr | 15725 Ntest
# 10 != 6
# SNRdb = 12 | 30 Nerr | 15789 Ntest
# 13 != 6
# SNRdb = 12 | 31 Nerr | 16443 Ntest
# 12 != 14
# SNRdb = 12 | 32 Nerr | 16793 Ntest
# 7 != 12
# SNRdb = 12 | 33 Nerr | 16991 Ntest
# 15 != 6
# SNRdb = 12 | 34 Nerr | 17361 Ntest
# 13 != 11
# SNRdb = 12 | 35 Nerr | 17927 Ntest
# 4 != 13
# SNRdb = 12 | 36 Nerr | 18967 Ntest
# 13 != 11
# SNRdb = 12 | 37 Nerr | 19615 Ntest
# 2 != 4
# SNRdb = 12 | 38 Nerr | 19874 Ntest
# 14 != 6
# SNRdb = 12 | 39 Nerr | 20135 Ntest
# 8 != 1
# SNRdb = 12 | 40 Nerr | 20207 Ntest
# 5 != 2
# SNRdb = 12 | 41 Nerr | 20682 Ntest
# 8 != 11
# SNRdb = 12 | 42 Nerr | 20958 Ntest
# 0 != 14
# SNRdb = 12 | 43 Nerr | 21324 Ntest
# 5 != 2
# SNRdb = 12 | 44 Nerr | 21571 Ntest
# 2 != 9
# SNRdb = 12 | 45 Nerr | 22719 Ntest
# 1 != 7
# SNRdb = 12 | 46 Nerr | 24121 Ntest
# 11 != 1
# SNRdb = 12 | 47 Nerr | 24708 Ntest
# 9 != 2
# SNRdb = 12 | 48 Nerr | 25925 Ntest
# 12 != 0
# SNRdb = 12 | 49 Nerr | 26108 Ntest
# 0 != 7
# SNRdb = 12 | 50 Nerr | 26526 Ntest
# Pe 0.0018848720171900327
# 8 != 12
# SNRdb = 13 | 1 Nerr | 5300 Ntest
# 10 != 5
# SNRdb = 13 | 2 Nerr | 8338 Ntest
# 5 != 11
# SNRdb = 13 | 3 Nerr | 9359 Ntest
# 4 != 0
# SNRdb = 13 | 4 Nerr | 14389 Ntest
# 12 != 10
# SNRdb = 13 | 5 Nerr | 24835 Ntest
# 15 != 13
# SNRdb = 13 | 6 Nerr | 25688 Ntest
# 3 != 4
# SNRdb = 13 | 7 Nerr | 28010 Ntest
# 10 != 12
# SNRdb = 13 | 8 Nerr | 30677 Ntest
# 3 != 1
# SNRdb = 13 | 9 Nerr | 31722 Ntest
# 6 != 0
# SNRdb = 13 | 10 Nerr | 33330 Ntest
# 6 != 9
# SNRdb = 13 | 11 Nerr | 40371 Ntest
# 7 != 5
# SNRdb = 13 | 12 Nerr | 44719 Ntest
# 0 != 7
# SNRdb = 13 | 13 Nerr | 47232 Ntest
# 13 != 11
# SNRdb = 13 | 14 Nerr | 53418 Ntest
# 5 != 14
# SNRdb = 13 | 15 Nerr | 54502 Ntest
# 7 != 13
# SNRdb = 13 | 16 Nerr | 57468 Ntest
# 1 != 8
# SNRdb = 13 | 17 Nerr | 62037 Ntest
# 12 != 7
# SNRdb = 13 | 18 Nerr | 67053 Ntest
# 11 != 6
# SNRdb = 13 | 19 Nerr | 67541 Ntest
# 6 != 12
# SNRdb = 13 | 20 Nerr | 79549 Ntest
# 5 != 3
# SNRdb = 13 | 21 Nerr | 81796 Ntest
# 1 != 13
# SNRdb = 13 | 22 Nerr | 82188 Ntest
# 3 != 0
# SNRdb = 13 | 23 Nerr | 88720 Ntest
# 13 != 2
# SNRdb = 13 | 24 Nerr | 92087 Ntest
# 10 != 0
# SNRdb = 13 | 25 Nerr | 95212 Ntest
# 8 != 4
# SNRdb = 13 | 26 Nerr | 95847 Ntest
# 1 != 13
# SNRdb = 13 | 27 Nerr | 100271 Ntest
# 15 != 6
# SNRdb = 13 | 28 Nerr | 110141 Ntest
# 1 != 12
# SNRdb = 13 | 29 Nerr | 116717 Ntest
# 2 != 10
# SNRdb = 13 | 30 Nerr | 124240 Ntest
# 2 != 5
# SNRdb = 13 | 31 Nerr | 125176 Ntest
# 11 != 5
# SNRdb = 13 | 32 Nerr | 130830 Ntest
# 3 != 13
# SNRdb = 13 | 33 Nerr | 131474 Ntest
# 5 != 7
# SNRdb = 13 | 34 Nerr | 133188 Ntest
# 14 != 12
# SNRdb = 13 | 35 Nerr | 137540 Ntest
# 13 != 8
# SNRdb = 13 | 36 Nerr | 140229 Ntest
# 9 != 12
# SNRdb = 13 | 37 Nerr | 141738 Ntest
# 9 != 8
# SNRdb = 13 | 38 Nerr | 142779 Ntest
# 5 != 15
# SNRdb = 13 | 39 Nerr | 145556 Ntest
# 12 != 6
# SNRdb = 13 | 40 Nerr | 151339 Ntest
# 10 != 4
# SNRdb = 13 | 41 Nerr | 152679 Ntest
# 11 != 10
# SNRdb = 13 | 42 Nerr | 152736 Ntest
# 9 != 11
# SNRdb = 13 | 43 Nerr | 154459 Ntest
# 4 != 11
# SNRdb = 13 | 44 Nerr | 160476 Ntest
# 0 != 12
# SNRdb = 13 | 45 Nerr | 163455 Ntest
# 5 != 6
# SNRdb = 13 | 46 Nerr | 168094 Ntest
# 4 != 0
# SNRdb = 13 | 47 Nerr | 168416 Ntest
# 14 != 1
# SNRdb = 13 | 48 Nerr | 169103 Ntest
# 11 != 0
# SNRdb = 13 | 49 Nerr | 174042 Ntest
# 8 != 6
# SNRdb = 13 | 50 Nerr | 175765 Ntest
# Pe 0.0002844691237213113
# 2 != 6
# SNRdb = 14 | 1 Nerr | 3497 Ntest
# 12 != 14
# SNRdb = 14 | 2 Nerr | 18727 Ntest
# 12 != 8
# SNRdb = 14 | 3 Nerr | 30781 Ntest
# 10 != 0
# SNRdb = 14 | 4 Nerr | 41034 Ntest
# 15 != 3
# SNRdb = 14 | 5 Nerr | 48085 Ntest
# 9 != 1
# SNRdb = 14 | 6 Nerr | 67552 Ntest
# 15 != 3
# SNRdb = 14 | 7 Nerr | 129069 Ntest
# 9 != 0
# SNRdb = 14 | 8 Nerr | 166966 Ntest
# 8 != 9
# SNRdb = 14 | 9 Nerr | 209740 Ntest
# 13 != 4
# SNRdb = 14 | 10 Nerr | 257372 Ntest
# 3 != 11
# SNRdb = 14 | 11 Nerr | 272114 Ntest
# > 300000 tests
# Pe ~= 0
# Pe 3.666654444485185e-05
